# %% [markdown]
# #PRODIGY_DS_04
#
# Task:4  Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands.
#
# Dataset Source: Kaggle
#
# Tool Used : Power BI
#
# Data Cleaning:
# The dataset is cleaned using Power Query feature of Power BI. It helps to clean and transform the data.

# %% [markdown]
# ![Screenshot (181).png](data:image/png;base64,...)

# %% [markdown]
# #Data Visualization
#
#
#
# * Brands by Sentiments
#
# ![Screenshot (183).png](data:image/png;base64,...)

# %% [markdown]
# *   Top 10 Brands by sentiments
#
# ![Screenshot (182).png](data:image/png;base64,...)

# %% [markdown]
# *   Count of sentiments by brands
#
# ![Screenshot (184).png](data:image/png;base64,...)
